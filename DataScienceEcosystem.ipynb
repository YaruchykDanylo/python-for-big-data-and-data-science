# %% [markdown]
# <a href="https://colab.research.google.com/github/YaruchykDanylo/python-for-big-data-and-data-science/blob/main/DataScienceEcosystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science on coursera

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ## Introduction
# Welcome to this notebook! In this notebook, we will explore various exercises related to data science and programming.

# %% [markdown]
# ### Data Science Languages
# - Python
# - R
# - SQL

# %% [markdown]
# ### Data Science Libraries
# - Pandas
# - NumPy
# - Matplotlib

# %% [markdown]
# ### Data Science Tools Table
#
# | Tool        | Description                 |
# |-------------|-----------------------------|
# | Jupyter     | Interactive notebooks       |
# | TensorFlow  | Deep learning framework     |
# | Scikit-learn| Machine learning library    |

# %% [markdown]
# ## Introduction to Arithmetic Expressions
# Arithmetic expressions involve mathematical operations such as addition, subtraction, multiplication, and division.

# %%
# Multiply and add numbers
a = 5
b = 3
multiply_result = a * b
add_result = a + b
print("Multiplication result:", multiply_result)
print("Addition result:", add_result)
# Out:
# Multiplication result: 15
# Addition result: 8

# %%
# Convert minutes to hours
minutes = 120
hours = minutes / 60
print("Hours:", hours)
# Out:
# Hours: 2.0

# %% [markdown]
# ## Author
# This notebook was created by [Danylo].
